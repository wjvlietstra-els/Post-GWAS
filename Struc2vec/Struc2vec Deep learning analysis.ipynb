# %% [markdown]
# # Deep learning test script

# %%
# Load the required packages
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping

# Load the required packages
import pandas as pd
from sklearn.svm import SVR
import json
import numpy as np

# %%
class_type = "autoencode"

# %%
# Load the data
if class_type == "normal":
    f = pd.read_csv("/Users/vlietstraw/git/Post-GWAS/Struc2vec/PathwayStudio_PPI_complete_directed_weighted.emb", sep = " ", skiprows = 1, header = None, index_col = 0)

# %%
# Load the autoencoded embeddings
if class_type == "autoencode":
    f = pd.read_csv("/Users/vlietstraw/git/Post-GWAS/Struc2vec/autorcode_weighted_emb.txt", sep = "\t", header = None)
    f.drop(columns = [350], inplace = True)
    f2 = pd.read_csv("/Users/vlietstraw/git/Post-GWAS/Struc2vec/PathwayStudio_PPI_complete_directed_weighted.emb", sep = " ", skiprows = 1, header = None, index_col = 0)
    f.index = f2.index

# %%
# Load the reference set
ref = pd.read_csv("/Users/vlietstraw/git/Post-GWAS/Input sets/Farashi/Farashi full 2000000 bp distance no pvalue filtering.csv")

# Load the mapping file
with open("/Users/vlietstraw/git/Post-GWAS/ENSEMBL_mappings.json", "r") as fp:
    ensembl_dict = json.load(fp)
ref["nodeID"] = [ensembl_dict[x] if x in ensembl_dict.keys() else None for x in ref["gene_ids"]]

# %%
# Drop all unmappable candidates
ref.dropna(subset = ["nodeID"], inplace = True)
ref["nodeID"] = ref["nodeID"].astype(int)

# %%
# Set bp distance cutoff
max_bp_distance = 2000
max_bp_distance = max_bp_distance * 1000
ref = ref[ref["bp distance absolute"] <= max_bp_distance]

# %%
# Drop all SNPs which no longer have a positive case
pos_counts = ref.groupby("SNP ID")["Class"].sum()
ref = ref[~ref["SNP ID"].isin(pos_counts[pos_counts == 0].index)]

# %%
# Identify all genes which are at least once positive
positives = ref.groupby("nodeID")["Class"].sum()
positives[positives > 1] = 1

f = f.merge(positives, left_index = True, right_index = True)

# %%
def createKeras(n_features):
  model = Sequential()
  model.add(Dense(230, input_dim = n_features, activation = "relu"))
  model.add(Dense(230, activation = "relu"))
  model.add(Dense(230, activation = "relu"))
  #model.add(Dense(32, activation = "relu"))
  model.add(Dense(1, activation = "sigmoid"))

  model.compile(loss = "binary_crossentropy",
                optimizer = "Adam",
                metrics = ["AUC"])
  return model

ES = EarlyStopping(monitor = 'loss', mode = 'min', patience = 3, min_delta = 0.025)

# %%
outcomes = pd.DataFrame()
train_auc_score = []
train_auc_rank = []

# %%
class_weights = { 0 : 1., 1 : round(len(f) / sum(f["Class"]), 2)}
aa = []
bb = []

# %%
# Perform leave-SNP-out cross validation
SNPs = list(set(ref["SNP ID"]))
for snp in SNPs:
    print("Predicting candidates for " + snp + ", number " + str(SNPs.index(snp) + 1) + " out of " + str(len(SNPs)))

    f_test = f[f.index.isin(ref[ref["SNP ID"] == snp]["nodeID"])].copy()
    f_train = f[f.index.isin(ref[ref["SNP ID"] != snp]["nodeID"])].copy()
    
    train_class = f["Class"][f.index.isin(f_train.index)]
    test_class = f["Class"][f.index.isin(f_test.index)]
    
    f_test.drop(columns = ["Class"], inplace = True)
    f_train.drop(columns = ["Class"], inplace = True)

    clf = None
    clf = createKeras(350)
    
    clf.fit(np.array(f_train), np.array(train_class), epochs = 25, verbose = 0, class_weight = class_weights, callbacks = [ES])
    
    a, b = clf.evaluate(np.array(f_test), np.array(test_class))
    
    aa.append(a)
    bb.append(b)

    outcomes = pd.concat([outcomes, pd.DataFrame({  "predicted" : [x[0] for x in clf.predict(np.array(f_test))],
                                                    "SNP ID" : snp,
                                                    "nodeID" : f_test.index})])
    
outcomes = outcomes.merge(ref[["SNP ID", "nodeID", "Class"]], on = ["SNP ID", "nodeID"], how = "left")
# Out:
# Predicting candidates for rs12682374, number 1 out of 194
# WARNING:tensorflow:From //anaconda3/envs/SNP-gene/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From //anaconda3/envs/SNP-gene/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 6/6 [==============================] - 0s 8ms/sample - loss: 0.7432 - auc: 0.8750
# Predicting candidates for rs10936845, number 2 out of 194
# 3/3 [==============================] - 0s 21ms/sample - loss: 2.7099 - auc_2: 0.2500
# Predicting candidates for rs34837204, number 3 out of 194
# 114/114 [==============================] - 0s 721us/sample - loss: 0.5853 - auc_4: 0.9236
# Predicting candidates for rs4976790, number 4 out of 194
# 53/53 [==============================] - 0s 2ms/sample - loss: 0.4837 - auc_6: 0.6731
# Predicting candidates for rs62003544, number 5 out of 194
# 24/24 [==============================] - 0s 5ms/sample - loss: 0.6541 - auc_8: 0.1957
# Predicting candidates for rs878987, number 6 out of 194
# 8/8 [==============================] - 0s 15ms/sample - loss: 1.5492 - auc_10: 0.2143
# Predicting candidates for rs13395911, number 7 out of 194
# 39/39 [==============================] - 0s 3ms/sample - loss: 0.8815 - auc_12: 0.4079
# Predicting candidates for rs12639887, number 8 out of 194
# 8/8 [==============================] - 0s 18ms/sample - loss: 0.2426 - auc_14: 1.0000
# Predicting candidates for rs3746337, number 9 out of 194
# 22/22 [==============================] - 0s 7ms/sample - loss: 0.2960 - auc_16: 0.8095
# Predicting candidates for rs461251, number 10 out of 194
# 39/39 [==============================] - 0s 5ms/sample - loss: 0.4055 - auc_18: 0.8143
# Predicting candidates for rs75513592, number 11 out of 194
# 31/31 [==============================] - 0s 6ms/sample - loss: 0.8065 - auc_20: 0.1500
# Predicting candidates for rs79618460, number 12 out of 194
# 21/21 [==============================] - 0s 10ms/sample - loss: 0.3495 - auc_22: 0.8421
# Predicting candidates for rs6557271, number 13 out of 194
# 14/14 [==============================] - 0s 16ms/sample - loss: 1.1454 - auc_24: 0.1923
# Predicting candidates for rs2412106, number 14 out of 194
# 21/21 [==============================] - 0s 11ms/sample - loss: 1.1954 - auc_26: 0.1500
# Predicting candidates for rs339343, number 15 out of 194
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.7325 - auc_28: 0.8333
# Predicting candidates for rs11263763, number 16 out of 194
# 47/47 [==============================] - 0s 6ms/sample - loss: 0.6444 - auc_30: 0.9773
# Predicting candidates for rs3135340, number 17 out of 194
# 119/119 [==============================] - 0s 2ms/sample - loss: 0.4500 - auc_32: 0.8835
# Predicting candidates for rs2045624, number 18 out of 194
# 55/55 [==============================] - 0s 5ms/sample - loss: 0.3554 - auc_34: 0.9828
# Predicting candidates for rs10122495, number 19 out of 194
# 59/59 [==============================] - 0s 5ms/sample - loss: 0.6084 - auc_36: 0.3103
# Predicting candidates for rs1160267, number 20 out of 194
# 42/42 [==============================] - 0s 8ms/sample - loss: 0.5913 - auc_38: 0.8125
# Predicting candidates for rs1242112, number 21 out of 194
# 33/33 [==============================] - 0s 11ms/sample - loss: 0.7085 - auc_40: 0.2812
# Predicting candidates for rs112262457, number 22 out of 194
# 29/29 [==============================] - 0s 12ms/sample - loss: 0.8340 - auc_42: 0.1964
# Predicting candidates for rs17024046, number 23 out of 194
# 7/7 [==============================] - 0s 52ms/sample - loss: 0.3708 - auc_44: 0.9000
# Predicting candidates for rs6702939, number 24 out of 194
# 15/15 [==============================] - 0s 25ms/sample - loss: 0.6950 - auc_46: 0.7857
# Predicting candidates for rs708723, number 25 out of 194
# 54/54 [==============================] - 0s 7ms/sample - loss: 0.4140 - auc_48: 0.9225
# Predicting candidates for rs58057291, number 26 out of 194
# 21/21 [==============================] - 0s 19ms/sample - loss: 0.5163 - auc_50: 0.8947
# Predicting candidates for rs7968403, number 27 out of 194
# 15/15 [==============================] - 0s 27ms/sample - loss: 0.6661 - auc_52: 0.5714
# Predicting candidates for rs6573971, number 28 out of 194
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.9628 - auc_54: 0.5526
# Predicting candidates for rs2659051, number 29 out of 194
# 88/88 [==============================] - 0s 5ms/sample - loss: 0.5193 - auc_56: 0.9451
# Predicting candidates for rs330999, number 30 out of 194
# 39/39 [==============================] - 0s 12ms/sample - loss: 0.4962 - auc_58: 0.9143
# Predicting candidates for rs448083, number 31 out of 194
# 77/77 [==============================] - 0s 6ms/sample - loss: 0.5872 - auc_60: 0.1711
# Predicting candidates for rs1058205, number 32 out of 194
# 87/87 [==============================] - 1s 6ms/sample - loss: 0.7897 - auc_62: 0.8294
# Predicting candidates for rs7323629, number 33 out of 194
# 10/10 [==============================] - 0s 49ms/sample - loss: 0.6827 - auc_64: 0.5556
# Predicting candidates for rs6899987, number 34 out of 194
# 22/22 [==============================] - 1s 24ms/sample - loss: 0.3761 - auc_66: 0.9298
# Predicting candidates for rs9269108, number 35 out of 194
# 120/120 [==============================] - 1s 4ms/sample - loss: 0.5183 - auc_68: 0.9177
# Predicting candidates for rs1320961, number 36 out of 194
# 19/19 [==============================] - 1s 28ms/sample - loss: 0.8359 - auc_70: 0.3889
# Predicting candidates for rs11986220, number 37 out of 194
# 6/6 [==============================] - 1s 92ms/sample - loss: 0.6774 - auc_72: 1.0000
# Predicting candidates for rs6799720, number 38 out of 194
# 8/8 [==============================] - 1s 70ms/sample - loss: 0.2918 - auc_74: 1.0000
# Predicting candidates for rs12655062, number 39 out of 194
# 24/24 [==============================] - 1s 25ms/sample - loss: 0.4063 - auc_76: 0.8938
# Predicting candidates for rs9979125, number 40 out of 194
# 42/42 [==============================] - 1s 15ms/sample - loss: 0.5072 - auc_78: 0.9187
# Predicting candidates for rs6545977, number 41 out of 194
# 21/21 [==============================] - 1s 30ms/sample - loss: 0.6867 - auc_80: 0.3500
# Predicting candidates for rs7295014, number 42 out of 194
# 16/16 [==============================] - 1s 40ms/sample - loss: 1.4591 - auc_82: 0.0667
# Predicting candidates for rs12785905, number 43 out of 194
# 102/102 [==============================] - 1s 6ms/sample - loss: 0.5187 - auc_84: 0.7250
# Predicting candidates for rs6730757, number 44 out of 194
# 18/18 [==============================] - 1s 36ms/sample - loss: 0.6316 - auc_86: 0.5882
# Predicting candidates for rs10069690, number 45 out of 194
# 23/23 [==============================] - 1s 29ms/sample - loss: 0.3613 - auc_88: 0.9342
# Predicting candidates for rs7632169, number 46 out of 194
# 34/34 [==============================] - 1s 21ms/sample - loss: 0.4699 - auc_90: 0.4848
# Predicting candidates for rs2742624, number 47 out of 194
# 22/22 [==============================] - 1s 31ms/sample - loss: 0.8073 - auc_92: 1.0000
# Predicting candidates for rs925013, number 48 out of 194
# 88/88 [==============================] - 1s 8ms/sample - loss: 0.5263 - auc_94: 0.8647
# Predicting candidates for rs182314334, number 49 out of 194
# 17/17 [==============================] - 1s 43ms/sample - loss: 0.8377 - auc_96: 0.5625
# Predicting candidates for rs74003103, number 50 out of 194
# 22/22 [==============================] - 1s 33ms/sample - loss: 0.2774 - auc_98: 0.9500
# Predicting candidates for rs78610930, number 51 out of 194
# 7/7 [==============================] - 1s 106ms/sample - loss: 0.3196 - auc_100: 0.8000
# Predicting candidates for rs183373024, number 52 out of 194
# 6/6 [==============================] - 1s 128ms/sample - loss: 0.4951 - auc_102: 1.0000
# Predicting candidates for rs9267853, number 53 out of 194
# 120/120 [==============================] - 1s 6ms/sample - loss: 0.5177 - auc_104: 0.9409
# Predicting candidates for rs8069005, number 54 out of 194
# 44/44 [==============================] - 1s 18ms/sample - loss: 0.6126 - auc_106: 0.2326
# Predicting candidates for rs12302939, number 55 out of 194
# 80/80 [==============================] - 1s 12ms/sample - loss: 0.1709 - auc_108: 0.9913
# Predicting candidates for rs12155172, number 56 out of 194
# 14/14 [==============================] - 1s 57ms/sample - loss: 0.7552 - auc_110: 0.5385
# Predicting candidates for rs7968852, number 57 out of 194
# 56/56 [==============================] - 1s 15ms/sample - loss: 0.2372 - auc_112: 0.9444
# Predicting candidates for rs708481, number 58 out of 194
# 6/6 [==============================] - 1s 138ms/sample - loss: 0.4970 - auc_114: 1.0000
# Predicting candidates for rs10792031, number 59 out of 194
# 51/51 [==============================] - 1s 17ms/sample - loss: 0.3052 - auc_116: 0.8214
# Predicting candidates for rs10280277, number 60 out of 194
# 8/8 [==============================] - 1s 105ms/sample - loss: 0.5725 - auc_118: 0.7143
# Predicting candidates for rs62113216, number 61 out of 194
# 87/87 [==============================] - 1s 10ms/sample - loss: 0.4947 - auc_120: 0.9782
# Predicting candidates for rs4325349, number 62 out of 194
# 86/86 [==============================] - 1s 10ms/sample - loss: 0.1935 - auc_122: 0.9880
# Predicting candidates for rs6977321, number 63 out of 194
# 28/28 [==============================] - 1s 32ms/sample - loss: 0.4273 - auc_124: 0.9615
# Predicting candidates for rs6096208, number 64 out of 194
# 26/26 [==============================] - 1s 35ms/sample - loss: 1.1586 - auc_126: 0.1000
# Predicting candidates for rs10182643, number 65 out of 194
# 11/11 [==============================] - 1s 86ms/sample - loss: 0.3669 - auc_128: 1.0000
# Predicting candidates for rs11891426, number 66 out of 194
# 21/21 [==============================] - 1s 48ms/sample - loss: 0.4233 - auc_130: 0.9605
# Predicting candidates for rs6738645, number 67 out of 194
# 31/31 [==============================] - 1s 31ms/sample - loss: 0.5563 - auc_132: 0.8793
# Predicting candidates for rs6057110, number 68 out of 194
# 10/10 [==============================] - 1s 96ms/sample - loss: 0.9395 - auc_134: 0.1111
# Predicting candidates for rs185397, number 69 out of 194
# 27/27 [==============================] - 1s 36ms/sample - loss: 0.5131 - auc_136: 0.9615
# Predicting candidates for rs4245739, number 70 out of 194
# 54/54 [==============================] - 1s 19ms/sample - loss: 0.4639 - auc_138: 0.9200
# Predicting candidates for rs76778410, number 71 out of 194
# 52/52 [==============================] - 1s 19ms/sample - loss: 0.5786 - auc_140: 0.8627
# Predicting candidates for rs61752561, number 72 out of 194
# 88/88 [==============================] - 1s 12ms/sample - loss: 0.5326 - auc_142: 0.9490
# Predicting candidates for rs7449190, number 73 out of 194
# 23/23 [==============================] - 1s 45ms/sample - loss: 0.3988 - auc_144: 0.9342
# Predicting candidates for rs1112444, number 74 out of 194
# 18/18 [==============================] - 1s 58ms/sample - loss: 0.3687 - auc_146: 0.9556
# Predicting candidates for rs914187, number 75 out of 194
# 39/39 [==============================] - 1s 27ms/sample - loss: 0.4467 - auc_148: 0.9730
# Predicting candidates for rs6760963, number 76 out of 194
# 21/21 [==============================] - 1s 51ms/sample - loss: 0.5115 - auc_150: 0.6316
# Predicting candidates for rs10795452, number 77 out of 194
# 17/17 [==============================] - 1s 67ms/sample - loss: 0.4966 - auc_152: 0.4375
# Predicting candidates for rs34695572, number 78 out of 194
# 24/24 [==============================] - 1s 46ms/sample - loss: 0.4556 - auc_154: 0.9187
# Predicting candidates for rs17239945, number 79 out of 194
# 24/24 [==============================] - 1s 48ms/sample - loss: 0.6913 - auc_156: 0.2174
# Predicting candidates for rs10059182, number 80 out of 194
# 11/11 [==============================] - 1s 105ms/sample - loss: 0.4657 - auc_158: 0.5000
# Predicting candidates for rs7223387, number 81 out of 194
# 47/47 [==============================] - 1s 25ms/sample - loss: 0.1606 - auc_160: 1.0000
# Predicting candidates for rs847377, number 82 out of 194
# 13/13 [==============================] - 1s 91ms/sample - loss: 0.5131 - auc_162: 0.5833
# Predicting candidates for rs135009, number 83 out of 194
# 44/44 [==============================] - 1s 27ms/sample - loss: 0.5937 - auc_164: 0.9593
# Predicting candidates for rs9925556, number 84 out of 194
# 105/105 [==============================] - 1s 13ms/sample - loss: 0.6226 - auc_166: 0.6202
# Predicting candidates for rs2555004, number 85 out of 194
# 17/17 [==============================] - 1s 71ms/sample - loss: 1.2947 - auc_168: 0.1250
# Predicting candidates for rs8107333, number 86 out of 194
# 74/74 [==============================] - 1s 17ms/sample - loss: 0.6379 - auc_170: 0.5753
# Predicting candidates for rs2452597, number 87 out of 194
# 8/8 [==============================] - 1s 157ms/sample - loss: 0.3415 - auc_172: 1.0000
# Predicting candidates for rs1045270, number 88 out of 194
# 18/18 [==============================] - 1s 71ms/sample - loss: 0.8001 - auc_174: 0.4118
# Predicting candidates for rs1250105, number 89 out of 194
# 36/36 [==============================] - 1s 36ms/sample - loss: 0.5078 - auc_176: 0.5143
# Predicting candidates for rs4830661, number 90 out of 194
# 13/13 [==============================] - 1s 99ms/sample - loss: 0.8377 - auc_178: 0.7273
# Predicting candidates for rs6444923, number 91 out of 194
# 17/17 [==============================] - 1s 77ms/sample - loss: 0.2765 - auc_180: 0.9333
# Predicting candidates for rs11689112, number 92 out of 194
# 16/16 [==============================] - 1s 82ms/sample - loss: 0.9516 - auc_182: 0.2333
# Predicting candidates for rs13137700, number 93 out of 194
# 33/33 [==============================] - 1s 41ms/sample - loss: 0.5549 - auc_184: 0.3281
# Predicting candidates for rs2253829, number 94 out of 194
# 50/50 [==============================] - 1s 28ms/sample - loss: 0.5310 - auc_186: 0.8750
# Predicting candidates for rs7885198, number 95 out of 194
# 11/11 [==============================] - 1s 126ms/sample - loss: 0.6505 - auc_188: 0.7000
# Predicting candidates for rs9267919, number 96 out of 194
# 120/120 [==============================] - 1s 12ms/sample - loss: 0.4403 - auc_190: 0.9532
# Predicting candidates for rs11629412, number 97 out of 194
# 18/18 [==============================] - 1s 79ms/sample - loss: 0.7599 - auc_192: 0.6471
# Predicting candidates for rs2130779, number 98 out of 194
# 22/22 [==============================] - 1s 64ms/sample - loss: 0.2728 - auc_194: 1.0000
# Predicting candidates for rs6001733, number 99 out of 194
# 64/64 [==============================] - 1s 22ms/sample - loss: 0.5435 - auc_196: 0.5556
# Predicting candidates for rs9296365, number 100 out of 194
# 50/50 [==============================] - 2s 31ms/sample - loss: 0.4517 - auc_198: 0.9929
# Predicting candidates for rs12976534, number 101 out of 194
# 74/74 [==============================] - 1s 20ms/sample - loss: 0.5990 - auc_200: 0.9167
# Predicting candidates for rs2569733, number 102 out of 194
# 88/88 [==============================] - 1s 17ms/sample - loss: 0.5916 - auc_202: 0.7706
# Predicting candidates for rs6512130, number 103 out of 194
# 88/88 [==============================] - 1s 17ms/sample - loss: 0.5850 - auc_204: 0.7701
# Predicting candidates for rs2242652, number 104 out of 194
# 23/23 [==============================] - 1s 65ms/sample - loss: 0.4253 - auc_206: 0.9605
# Predicting candidates for rs16860643, number 105 out of 194
# 21/21 [==============================] - 2s 72ms/sample - loss: 0.6253 - auc_208: 0.2500
# Predicting candidates for rs3129887, number 106 out of 194
# 119/119 [==============================] - 2s 13ms/sample - loss: 0.4223 - auc_210: 0.9491
# Predicting candidates for rs3105751, number 107 out of 194
# 18/18 [==============================] - 2s 86ms/sample - loss: 0.2848 - auc_212: 0.9778
# Predicting candidates for rs1188529, number 108 out of 194
# 45/45 [==============================] - 2s 35ms/sample - loss: 0.4834 - auc_214: 0.9651
# Predicting candidates for rs6785962, number 109 out of 194
# 22/22 [==============================] - 2s 71ms/sample - loss: 0.5326 - auc_216: 0.9524
# Predicting candidates for rs7625643, number 110 out of 194
# 20/20 [==============================] - 2s 78ms/sample - loss: 1.2050 - auc_218: 0.5263
# Predicting candidates for rs11666569, number 111 out of 194
# 83/83 [==============================] - 2s 19ms/sample - loss: 0.5622 - auc_220: 0.7073
# Predicting candidates for rs12360799, number 112 out of 194
# 27/27 [==============================] - 2s 60ms/sample - loss: 0.5409 - auc_222: 0.1346
# Predicting candidates for rs2384958, number 113 out of 194
# 21/21 [==============================] - 2s 78ms/sample - loss: 0.7016 - auc_224: 1.0000
# Predicting candidates for rs2401138, number 114 out of 194
# 29/29 [==============================] - 2s 57ms/sample - loss: 0.5050 - auc_226: 1.0000
# Predicting candidates for rs7725218, number 115 out of 194
# 23/23 [==============================] - 2s 71ms/sample - loss: 0.7132 - auc_228: 0.9342
# Predicting candidates for rs17122571, number 116 out of 194
# 55/55 [==============================] - 2s 31ms/sample - loss: 0.3290 - auc_230: 0.9340
# Predicting candidates for rs1891805, number 117 out of 194
# 116/116 [==============================] - 2s 15ms/sample - loss: 0.4599 - auc_232: 0.8421
# Predicting candidates for rs3821747, number 118 out of 194
# 19/19 [==============================] - 2s 93ms/sample - loss: 0.6469 - auc_234: 0.8824
# Predicting candidates for rs1218582, number 119 out of 194
# 115/115 [==============================] - 2s 15ms/sample - loss: 0.4362 - auc_236: 0.9823
# Predicting candidates for rs1048169, number 120 out of 194
# 13/13 [==============================] - 2s 130ms/sample - loss: 0.9772 - auc_238: 0.2083
# Predicting candidates for rs6735152, number 121 out of 194
# 31/31 [==============================] - 2s 57ms/sample - loss: 0.6409 - auc_240: 0.7414
# Predicting candidates for rs112871784, number 122 out of 194
# 23/23 [==============================] - 2s 75ms/sample - loss: 0.3723 - auc_242: 0.9091
# Predicting candidates for rs3798439, number 123 out of 194
# 9/9 [==============================] - 2s 193ms/sample - loss: 1.6271 - auc_244: 0.1875
# Predicting candidates for rs3771578, number 124 out of 194
# 23/23 [==============================] - 2s 76ms/sample - loss: 0.5299 - auc_246: 0.8182
# Predicting candidates for rs4907792, number 125 out of 194
# 21/21 [==============================] - 2s 85ms/sample - loss: 0.6469 - auc_248: 0.8500
# Predicting candidates for rs12631116, number 126 out of 194
# 33/33 [==============================] - 2s 56ms/sample - loss: 1.0393 - auc_250: 0.0938
# Predicting candidates for rs9940142, number 127 out of 194
# 31/31 [==============================] - 2s 58ms/sample - loss: 0.7037 - auc_252: 1.0000
# Predicting candidates for rs12137162, number 128 out of 194
# 31/31 [==============================] - 2s 60ms/sample - loss: 0.6205 - auc_254: 0.1667
# Predicting candidates for rs6011058, number 129 out of 194
# 50/50 [==============================] - 2s 39ms/sample - loss: 0.6406 - auc_256: 0.9375
# Predicting candidates for rs11168936, number 130 out of 194
# 66/66 [==============================] - 2s 29ms/sample - loss: 0.2629 - auc_258: 0.8828
# Predicting candidates for rs10100297, number 131 out of 194
# 12/12 [==============================] - 2s 157ms/sample - loss: 0.8515 - auc_260: 0.3182
# Predicting candidates for rs11568311, number 132 out of 194
# 60/60 [==============================] - 2s 32ms/sample - loss: 0.2116 - auc_262: 0.8220
# Predicting candidates for rs3096702, number 133 out of 194
# 120/120 [==============================] - 2s 16ms/sample - loss: 0.5857 - auc_264: 0.9300
# Predicting candidates for rs1476161, number 134 out of 194
# 84/84 [==============================] - 2s 23ms/sample - loss: 0.4108 - auc_266: 0.8994
# Predicting candidates for rs651164, number 135 out of 194
# 20/20 [==============================] - 2s 102ms/sample - loss: 0.4380 - auc_268: 0.9804
# Predicting candidates for rs8134378, number 136 out of 194
# 42/42 [==============================] - 2s 47ms/sample - loss: 0.2839 - auc_270: 0.9812
# Predicting candidates for rs4430796, number 137 out of 194
# 47/47 [==============================] - 2s 42ms/sample - loss: 0.1383 - auc_272: 1.0000
# Predicting candidates for rs742136, number 138 out of 194
# 45/45 [==============================] - 2s 44ms/sample - loss: 0.4791 - auc_274: 0.9524
# Predicting candidates for rs2474694, number 139 out of 194
# 39/39 [==============================] - 2s 54ms/sample - loss: 0.6648 - auc_276: 0.9214
# Predicting candidates for rs11247571, number 140 out of 194
# 40/40 [==============================] - 2s 50ms/sample - loss: 0.4520 - auc_278: 0.8611
# Predicting candidates for rs12938215, number 141 out of 194
# 47/47 [==============================] - 2s 43ms/sample - loss: 0.4227 - auc_280: 1.0000
# Predicting candidates for rs4468286, number 142 out of 194
# 23/23 [==============================] - 2s 93ms/sample - loss: 0.4872 - auc_282: 0.8421
# Predicting candidates for rs785373, number 143 out of 194
# 11/11 [==============================] - 2s 196ms/sample - loss: 0.4676 - auc_284: 0.7000
# Predicting candidates for rs12656007, number 144 out of 194
# 24/24 [==============================] - 2s 85ms/sample - loss: 0.6192 - auc_286: 0.9250
# Predicting candidates for rs17774188, number 145 out of 194
# 41/41 [==============================] - 2s 50ms/sample - loss: 0.4542 - auc_288: 0.7500
# Predicting candidates for rs73106451, number 146 out of 194
# 82/82 [==============================] - 2s 26ms/sample - loss: 0.4142 - auc_290: 0.9135
# Predicting candidates for rs2456274, number 147 out of 194
# 39/39 [==============================] - 2s 54ms/sample - loss: 0.4496 - auc_292: 0.9071
# Predicting candidates for rs3755718, number 148 out of 194
# 10/10 [==============================] - 2s 227ms/sample - loss: 0.7210 - auc_294: 0.5556
# Predicting candidates for rs9856752, number 149 out of 194
# 7/7 [==============================] - 2s 303ms/sample - loss: 0.3697 - auc_296: 0.9000
# Predicting candidates for rs4698932, number 150 out of 194
# 14/14 [==============================] - 2s 151ms/sample - loss: 1.0093 - auc_298: 0.0385
# Predicting candidates for rs12653946, number 151 out of 194
# 24/24 [==============================] - 2s 89ms/sample - loss: 0.4442 - auc_300: 0.9250
# Predicting candidates for rs34349481, number 152 out of 194
# 25/25 [==============================] - 2s 87ms/sample - loss: 0.4354 - auc_302: 0.8636
# Predicting candidates for rs3847414, number 153 out of 194
# 10/10 [==============================] - 2s 217ms/sample - loss: 2.2526 - auc_304: 0.0556
# Predicting candidates for rs2289081, number 154 out of 194
# 11/11 [==============================] - 2s 199ms/sample - loss: 0.2896 - auc_306: 1.0000
# Predicting candidates for rs1265109, number 155 out of 194
# 113/113 [==============================] - 2s 20ms/sample - loss: 0.5838 - auc_308: 0.9728
# Predicting candidates for rs9368661, number 156 out of 194
# 113/113 [==============================] - 2s 20ms/sample - loss: 0.6602 - auc_310: 0.9427
# Predicting candidates for rs12419367, number 157 out of 194
# 70/70 [==============================] - 2s 33ms/sample - loss: 0.4960 - auc_312: 0.6667
# Predicting candidates for rs2739448, number 158 out of 194
# 88/88 [==============================] - 3s 33ms/sample - loss: 0.3933 - auc_314: 0.9353
# Predicting candidates for rs12981216, number 159 out of 194
# 74/74 [==============================] - 3s 39ms/sample - loss: 0.3739 - auc_316: 0.9688
# Predicting candidates for rs1983891, number 160 out of 194
# 50/50 [==============================] - 3s 57ms/sample - loss: 0.5124 - auc_318: 0.9326
# Predicting candidates for rs7581701, number 161 out of 194
# 22/22 [==============================] - 3s 142ms/sample - loss: 0.5465 - auc_320: 0.5714
# Predicting candidates for rs747181, number 162 out of 194
# 32/32 [==============================] - 3s 90ms/sample - loss: 0.6268 - auc_322: 0.8966
# Predicting candidates for rs11191385, number 163 out of 194
# 24/24 [==============================] - 2s 98ms/sample - loss: 0.3932 - auc_324: 0.9524
# Predicting candidates for rs10144415, number 164 out of 194
# 15/15 [==============================] - 2s 156ms/sample - loss: 0.3640 - auc_326: 0.9286
# Predicting candidates for rs10486567, number 165 out of 194
# 25/25 [==============================] - 2s 95ms/sample - loss: 0.3069 - auc_328: 0.8750
# Predicting candidates for rs4962720, number 166 out of 194
# 17/17 [==============================] - 2s 141ms/sample - loss: 0.3493 - auc_330: 0.9000
# Predicting candidates for rs3129878, number 167 out of 194
# 119/119 [==============================] - 2s 20ms/sample - loss: 0.4730 - auc_332: 0.9220
# Predicting candidates for rs6557694, number 168 out of 194
# 41/41 [==============================] - 2s 59ms/sample - loss: 0.5218 - auc_334: 0.9359
# Predicting candidates for rs2014202, number 169 out of 194
# 54/54 [==============================] - 3s 47ms/sample - loss: 0.5497 - auc_336: 0.8825
# Predicting candidates for rs12453443, number 170 out of 194
# 47/47 [==============================] - 2s 52ms/sample - loss: 0.3154 - auc_338: 0.9886
# Predicting candidates for rs17632542, number 171 out of 194
# 88/88 [==============================] - 2s 28ms/sample - loss: 0.3690 - auc_340: 0.8098
# Predicting candidates for rs2736100, number 172 out of 194
# 23/23 [==============================] - 2s 108ms/sample - loss: 0.4606 - auc_342: 0.9474
# Predicting candidates for rs35010507, number 173 out of 194
# 24/24 [==============================] - 2s 103ms/sample - loss: 0.6239 - auc_344: 0.9187
# Predicting candidates for rs1436642, number 174 out of 194
# 7/7 [==============================] - 3s 440ms/sample - loss: 0.4251 - auc_346: 1.0000
# Predicting candidates for rs4962416, number 175 out of 194
# 17/17 [==============================] - 3s 149ms/sample - loss: 0.4426 - auc_348: 0.8667
# Predicting candidates for rs34884832, number 176 out of 194
# 21/21 [==============================] - 3s 121ms/sample - loss: 0.3082 - auc_350: 0.7500
# Predicting candidates for rs2011345, number 177 out of 194
# 23/23 [==============================] - 3s 113ms/sample - loss: 0.7827 - auc_352: 0.4545
# Predicting candidates for rs75056606, number 178 out of 194
# 80/80 [==============================] - 3s 32ms/sample - loss: 0.4612 - auc_354: 0.9199
# Predicting candidates for rs10054203, number 179 out of 194
# 23/23 [==============================] - 3s 115ms/sample - loss: 0.4762 - auc_356: 0.9211
# Predicting candidates for rs6983267, number 180 out of 194
# 6/6 [==============================] - 3s 426ms/sample - loss: 0.6675 - auc_358: 0.7500
# Predicting candidates for rs28441558, number 181 out of 194
# 81/81 [==============================] - 3s 32ms/sample - loss: 0.3102 - auc_360: 0.9620
# Predicting candidates for rs339331, number 182 out of 194
# 20/20 [==============================] - 3s 131ms/sample - loss: 0.9092 - auc_362: 0.8194
# Predicting candidates for rs7934971, number 183 out of 194
# 46/46 [==============================] - 3s 56ms/sample - loss: 0.8482 - auc_364: 0.1778
# Predicting candidates for rs11568818, number 184 out of 194
# 21/21 [==============================] - 3s 126ms/sample - loss: 1.5238 - auc_366: 0.1250
# Predicting candidates for rs5937025, number 185 out of 194
# 27/27 [==============================] - 3s 101ms/sample - loss: 0.4633 - auc_368: 0.9583
# Predicting candidates for rs437948, number 186 out of 194
# 39/39 [==============================] - 3s 69ms/sample - loss: 0.8160 - auc_370: 0.8321
# Predicting candidates for rs6958572, number 187 out of 194
# 28/28 [==============================] - 3s 95ms/sample - loss: 0.3753 - auc_372: 1.0000
# Predicting candidates for rs9469899, number 188 out of 194
# 68/68 [==============================] - 3s 43ms/sample - loss: 0.5901 - auc_374: 0.3806
# Predicting candidates for rs2283119, number 189 out of 194
# 19/19 [==============================] - 3s 143ms/sample - loss: 0.7424 - auc_376: 0.6111
# Predicting candidates for rs868868, number 190 out of 194
# 118/118 [==============================] - 3s 23ms/sample - loss: 0.5413 - auc_378: 0.9739
# Predicting candidates for rs3786877, number 191 out of 194
# 75/75 [==============================] - 3s 37ms/sample - loss: 0.7943 - auc_380: 0.7774
# Predicting candidates for rs1341051, number 192 out of 194
# 20/20 [==============================] - 3s 137ms/sample - loss: 0.5363 - auc_382: 0.6842
# Predicting candidates for rs1010, number 193 out of 194
# 31/31 [==============================] - 3s 90ms/sample - loss: 0.6510 - auc_384: 0.9052
# Predicting candidates for rs61890184, number 194 out of 194
# 44/44 [==============================] - 3s 64ms/sample - loss: 0.4050 - auc_386: 0.6977

# %%
outcomes = outcomes.sort_values(["SNP ID", "predicted"], ascending = False)
outcomes["For-SNP rank"] = outcomes.groupby("SNP ID").cumcount() + 1

# %%
import sklearn.metrics

fpr, tpr, thresholds = sklearn.metrics.roc_curve(outcomes["Class"], -outcomes["For-SNP rank"], pos_label = 1)
print(sklearn.metrics.auc(fpr, tpr) * 100)
# Out:
# 81.23034111812352

# %%
print(np.mean(bb))
# Out:
# 0.7430851

# %%
# Calculate the ROC-AUC for every SNP and average the result
SNPS2 = list(set(outcomes["SNP ID"]))
aucs = []
for snp in SNPS2:
  if len(set(outcomes["Class"][outcomes["SNP ID"] == snp])) == 1:
      aucs.append(list(set(outcomes["Class"][outcomes["SNP ID"] == snp]))[0])
  else:
      fpr, tpr, thresholds = sklearn.metrics.roc_curve(outcomes["Class"][outcomes["SNP ID"] == snp], -outcomes["For-SNP rank"][outcomes["SNP ID"] == snp], pos_label = 1)
      aucs.append(sklearn.metrics.auc(fpr, tpr))
print(sum(aucs)/len(aucs))
# Out:
# 0.7280879634861137
